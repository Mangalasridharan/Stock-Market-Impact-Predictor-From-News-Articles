# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import torch
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/content/drive/MyDrive/preprocessed_fnspid_10k.csv")
df
# Out:
#                                           Article_title Stock_symbol  \
# 0     5 Growth Stocks at New Highs with Room for Mor...          ADM
# 1     3 Strong Buy Semiconductor Stocks to Consider Now         AMAT
# 2     Pfizer's Breast Cancer Drug Misses Overall Sur...         ANIP
# 3     Microsoft to Launch Second-Gen Hololens AR Hea...           AR
# 4     Camden Property Trust (CPT) Ex-Dividend Date S...          AMT
# ...                                                 ...          ...
# 9995  What Makes Jakks Pacific (JAKK) a Strong Momen...         AFGD
# 9996  Is Bunge Limited (BG) Stock Undervalued Right ...           BG
# 9997  Is Wingstop (WING) a Solid Growth Stock? 3 Rea...         ARGD
# 9998  3 Nasdaq Stocks That Have Generated 10x Return...         AAPL
# 9999  Tesla (TSLA) Recalls 2M Vehicles to Fix Autopi...         ARGD
#
#                                                 Article  \
# 0     Amid the ongoing trade tensions between the Un...
# 1     Semiconductor stocks were battered by the rece...
# 2     Pfizer PFE announced disappointing overall sur...
# 3     Microsoft is getting ready to launch the next ...
# 4     Camden Property Trust ( CPT ) will begin tradi...
# ...                                                 ...
# 9995  Momentum investing revolves around the idea of...
# 9996  The proven Zacks Rank system focuses on earnin...
# 9997  Growth investors focus on stocks that are seei...
# 9998  The Nasdaq is home to many of the best growth ...
# 9999  Tesla TSLA is recalling more than 2 million ve...
#
#                                        Textrank_summary  \
# 0     Click to get this free report NetApp, Inc. (NT...
# 1     Click to get this free report Apple Inc. (AAPL...
# 2     Click to get this free report AstraZeneca PLC ...
# 3     Microsoft is getting ready to launch the next ...
# 4     CPT is a part of the Consumer Services sector,...
# ...                                                 ...
# 9995  Our research shows that stocks rated Zacks Ran...
# 9996  Click to get this free report Bunge Limited (B...
# 9997  However, the task of finding cutting-edge grow...
# 9998  Some of them have generated life-changing retu...
# 9999  Per Part 573 Recall report, the company is pla...
#
#                                    Preprocessed_Summary Sentiment  Confidence
# 0     click to get this free report netapp, inc. nta...   Neutral    0.744207
# 1     click to get this free report apple inc. aapl ...  Positive    0.633728
# 2     click to get this free report astrazeneca plc ...  Positive    0.504592
# 3     microsoft is getting ready to launch the next ...   Neutral    0.947672
# 4     cpt is a part of the consumer services sector,...  Negative    0.547460
# ...                                                 ...       ...         ...
# 9995  our research shows that stocks rated zacks ran...   Neutral    0.930927
# 9996  click to get this free report bunge limited bg...   Neutral    0.925172
# 9997  however, the task of finding cutting edge grow...   Neutral    0.758138
# 9998  some of them have generated life changing retu...  Positive    0.738722
# 9999  per part 573 recall report, the company is pla...   Neutral    0.947333
#
# [10000 rows x 7 columns]

# %%
model_name = "mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/933 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]

# %%
target_label = df['Sentiment'].unique()
print(target_label)
# Out:
# ['Neutral' 'Positive' 'Negative']

# %%
label2id = {"Negative": 0, "Neutral": 1, "Positive": 2}
id2label = {v: k for k, v in label2id.items()}
df["label"] = df["Sentiment"].map(label2id)

# %%
df
# Out:
#                                           Article_title Stock_symbol  \
# 0     5 Growth Stocks at New Highs with Room for Mor...          ADM
# 1     3 Strong Buy Semiconductor Stocks to Consider Now         AMAT
# 2     Pfizer's Breast Cancer Drug Misses Overall Sur...         ANIP
# 3     Microsoft to Launch Second-Gen Hololens AR Hea...           AR
# 4     Camden Property Trust (CPT) Ex-Dividend Date S...          AMT
# ...                                                 ...          ...
# 9995  What Makes Jakks Pacific (JAKK) a Strong Momen...         AFGD
# 9996  Is Bunge Limited (BG) Stock Undervalued Right ...           BG
# 9997  Is Wingstop (WING) a Solid Growth Stock? 3 Rea...         ARGD
# 9998  3 Nasdaq Stocks That Have Generated 10x Return...         AAPL
# 9999  Tesla (TSLA) Recalls 2M Vehicles to Fix Autopi...         ARGD
#
#                                                 Article  \
# 0     Amid the ongoing trade tensions between the Un...
# 1     Semiconductor stocks were battered by the rece...
# 2     Pfizer PFE announced disappointing overall sur...
# 3     Microsoft is getting ready to launch the next ...
# 4     Camden Property Trust ( CPT ) will begin tradi...
# ...                                                 ...
# 9995  Momentum investing revolves around the idea of...
# 9996  The proven Zacks Rank system focuses on earnin...
# 9997  Growth investors focus on stocks that are seei...
# 9998  The Nasdaq is home to many of the best growth ...
# 9999  Tesla TSLA is recalling more than 2 million ve...
#
#                                        Textrank_summary  \
# 0     Click to get this free report NetApp, Inc. (NT...
# 1     Click to get this free report Apple Inc. (AAPL...
# 2     Click to get this free report AstraZeneca PLC ...
# 3     Microsoft is getting ready to launch the next ...
# 4     CPT is a part of the Consumer Services sector,...
# ...                                                 ...
# 9995  Our research shows that stocks rated Zacks Ran...
# 9996  Click to get this free report Bunge Limited (B...
# 9997  However, the task of finding cutting-edge grow...
# 9998  Some of them have generated life-changing retu...
# 9999  Per Part 573 Recall report, the company is pla...
#
#                                    Preprocessed_Summary Sentiment  Confidence  \
# 0     click to get this free report netapp, inc. nta...   Neutral    0.744207
# 1     click to get this free report apple inc. aapl ...  Positive    0.633728
# 2     click to get this free report astrazeneca plc ...  Positive    0.504592
# 3     microsoft is getting ready to launch the next ...   Neutral    0.947672
# 4     cpt is a part of the consumer services sector,...  Negative    0.547460
# ...                                                 ...       ...         ...
# 9995  our research shows that stocks rated zacks ran...   Neutral    0.930927
# 9996  click to get this free report bunge limited bg...   Neutral    0.925172
# 9997  however, the task of finding cutting edge grow...   Neutral    0.758138
# 9998  some of them have generated life changing retu...  Positive    0.738722
# 9999  per part 573 recall report, the company is pla...   Neutral    0.947333
#
#       label
# 0         1
# 1         2
# 2         2
# 3         1
# 4         0
# ...     ...
# 9995      1
# 9996      1
# 9997      1
# 9998      2
# 9999      1
#
# [10000 rows x 8 columns]

# %%
import regex as re

# %%
def clean_text(text):
  if pd.isna(text):
    return ""
  text=str(text).lower()
  text=re.sub(r"https\S+|www\S+","",text)
  text=re.sub(r"<.*?>","",text)
  text=re.sub(r"[^a-zA-Z0-9$.,!?%]"," ",text)
  text=re.sub(r"\s+"," ",text).strip()
  return text

# %%
df["Preprocessed_Article_title"]=df["Article_title"].apply(clean_text)
df["Preprocessed_Article"] = df["Article"].apply(clean_text)
df
# Out:
#                                           Article_title Stock_symbol  \
# 0     5 Growth Stocks at New Highs with Room for Mor...          ADM
# 1     3 Strong Buy Semiconductor Stocks to Consider Now         AMAT
# 2     Pfizer's Breast Cancer Drug Misses Overall Sur...         ANIP
# 3     Microsoft to Launch Second-Gen Hololens AR Hea...           AR
# 4     Camden Property Trust (CPT) Ex-Dividend Date S...          AMT
# ...                                                 ...          ...
# 9995  What Makes Jakks Pacific (JAKK) a Strong Momen...         AFGD
# 9996  Is Bunge Limited (BG) Stock Undervalued Right ...           BG
# 9997  Is Wingstop (WING) a Solid Growth Stock? 3 Rea...         ARGD
# 9998  3 Nasdaq Stocks That Have Generated 10x Return...         AAPL
# 9999  Tesla (TSLA) Recalls 2M Vehicles to Fix Autopi...         ARGD
#
#                                                 Article  \
# 0     Amid the ongoing trade tensions between the Un...
# 1     Semiconductor stocks were battered by the rece...
# 2     Pfizer PFE announced disappointing overall sur...
# 3     Microsoft is getting ready to launch the next ...
# 4     Camden Property Trust ( CPT ) will begin tradi...
# ...                                                 ...
# 9995  Momentum investing revolves around the idea of...
# 9996  The proven Zacks Rank system focuses on earnin...
# 9997  Growth investors focus on stocks that are seei...
# 9998  The Nasdaq is home to many of the best growth ...
# 9999  Tesla TSLA is recalling more than 2 million ve...
#
#                                        Textrank_summary  \
# 0     Click to get this free report NetApp, Inc. (NT...
# 1     Click to get this free report Apple Inc. (AAPL...
# 2     Click to get this free report AstraZeneca PLC ...
# 3     Microsoft is getting ready to launch the next ...
# 4     CPT is a part of the Consumer Services sector,...
# ...                                                 ...
# 9995  Our research shows that stocks rated Zacks Ran...
# 9996  Click to get this free report Bunge Limited (B...
# 9997  However, the task of finding cutting-edge grow...
# 9998  Some of them have generated life-changing retu...
# 9999  Per Part 573 Recall report, the company is pla...
#
#                                    Preprocessed_Summary Sentiment  Confidence  \
# 0     click to get this free report netapp, inc. nta...   Neutral    0.744207
# 1     click to get this free report apple inc. aapl ...  Positive    0.633728
# 2     click to get this free report astrazeneca plc ...  Positive    0.504592
# 3     microsoft is getting ready to launch the next ...   Neutral    0.947672
# 4     cpt is a part of the consumer services sector,...  Negative    0.547460
# ...                                                 ...       ...         ...
# 9995  our research shows that stocks rated zacks ran...   Neutral    0.930927
# 9996  click to get this free report bunge limited bg...   Neutral    0.925172
# 9997  however, the task of finding cutting edge grow...   Neutral    0.758138
# 9998  some of them have generated life changing retu...  Positive    0.738722
# 9999  per part 573 recall report, the company is pla...   Neutral    0.947333
#
#       label                         Preprocessed_Article_title  \
# 0         1  5 growth stocks at new highs with room for mor...
# 1         2  3 strong buy semiconductor stocks to consider now
# 2         2  pfizer s breast cancer drug misses overall sur...
# 3         1  microsoft to launch second gen hololens ar hea...
# 4         0  camden property trust cpt ex dividend date sch...
# ...     ...                                                ...
# 9995      1  what makes jakks pacific jakk a strong momentu...
# 9996      1   is bunge limited bg stock undervalued right now?
# 9997      1  is wingstop wing a solid growth stock? 3 reaso...
# 9998      2  3 nasdaq stocks that have generated 10x return...
# 9999      1  tesla tsla recalls 2m vehicles to fix autopilo...
#
#                                    Preprocessed_Article
# 0     amid the ongoing trade tensions between the un...
# 1     semiconductor stocks were battered by the rece...
# 2     pfizer pfe announced disappointing overall sur...
# 3     microsoft is getting ready to launch the next ...
# 4     camden property trust cpt will begin trading e...
# ...                                                 ...
# 9995  momentum investing revolves around the idea of...
# 9996  the proven zacks rank system focuses on earnin...
# 9997  growth investors focus on stocks that are seei...
# 9998  the nasdaq is home to many of the best growth ...
# 9999  tesla tsla is recalling more than 2 million ve...
#
# [10000 rows x 10 columns]

# %%
from datasets import Dataset

dataset = Dataset.from_pandas(df[["Preprocessed_Article", "label"]])

# %%
dataset = dataset.train_test_split(test_size=0.1, seed=42)
train_dataset = dataset["train"]
val_dataset = dataset["test"]

# %%
# !pip install evaluate

# %%
def preprocess_function(examples):
    texts = examples["Preprocessed_Article"]
    labels = examples["label"]

    tokenized_inputs = tokenizer(
        texts,
        truncation=True,
        padding="max_length",
        max_length=512,
        stride=128,
        return_overflowing_tokens=True,
        return_offsets_mapping=False
    )

    flattened_input_ids = []
    flattened_attention_mask = []
    flattened_labels = []

    for i in range(len(tokenized_inputs["input_ids"])):
        original_sample_index = tokenized_inputs["overflow_to_sample_mapping"][i]
        flattened_input_ids.append(tokenized_inputs["input_ids"][i])
        flattened_attention_mask.append(tokenized_inputs["attention_mask"][i])
        flattened_labels.append(labels[original_sample_index])

    return {
        "input_ids": flattened_input_ids,
        "attention_mask": flattened_attention_mask,
        "labels": flattened_labels
    }

# %%
processed_dataset = Dataset.from_pandas(df[["Preprocessed_Article", "label"]]).map(
    preprocess_function,
    batched=True,
    remove_columns=["Preprocessed_Article", "label"]
)

dataset = processed_dataset.train_test_split(test_size=0.1, seed=42)
train_dataset = dataset["train"]
val_dataset = dataset["test"]
# Out:
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    return {
        "accuracy": accuracy_score(labels, preds),
        "f1": f1_score(labels, preds, average="weighted")
    }

# %%
training_args = TrainingArguments(
    output_dir="./distilroberta-results",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=100,
    load_best_model_at_end=True,
    save_total_limit=2
)

# -------------------------
# Trainer
# -------------------------
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# /tmp/ipython-input-1185205517.py:19: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='10275' max='10275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10275/10275 1:11:00, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.603500</td>
#       <td>0.772474</td>
#       <td>0.686268</td>
#       <td>0.687108</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.524400</td>
#       <td>0.728296</td>
#       <td>0.708279</td>
#       <td>0.709463</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.404100</td>
#       <td>0.770384</td>
#       <td>0.722076</td>
#       <td>0.723507</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10275, training_loss=0.5283337714202213, metrics={'train_runtime': 4260.8362, 'train_samples_per_second': 19.289, 'train_steps_per_second': 2.411, 'total_flos': 1.0887424719040512e+16, 'train_loss': 0.5283337714202213, 'epoch': 3.0})

# %%
results = trainer.evaluate()
print("Final evaluation:", results)
# Out:
#     <div>
#
#       <progress value='381' max='381' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [381/381 00:44]
#     </div>
# Final evaluation: {'eval_loss': 0.728296160697937, 'eval_accuracy': 0.7082785808147175, 'eval_f1': 0.7094629083906407, 'eval_runtime': 44.7492, 'eval_samples_per_second': 68.024, 'eval_steps_per_second': 8.514, 'epoch': 3.0}

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Predictions
preds = trainer.predict(val_dataset)
y_true = preds.label_ids
y_pred = np.argmax(preds.predictions, axis=1)

# Report
print(classification_report(y_true, y_pred, target_names=["Positive","Negative","Neutral"]))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Positive","Negative","Neutral"], yticklabels=["Positive","Negative","Neutral"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     Positive       0.61      0.64      0.63       574
#     Negative       0.81      0.79      0.80      1666
#      Neutral       0.58      0.59      0.59       804
#
#     accuracy                           0.71      3044
#    macro avg       0.67      0.67      0.67      3044
# weighted avg       0.71      0.71      0.71      3044

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

y_true = val_dataset["labels"]
y_pred = np.argmax(trainer.predict(val_dataset).predictions, axis=-1)
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Negative", "Neutral", "Positive"])
disp.plot(cmap=plt.cm.Blues)
plt.show()
