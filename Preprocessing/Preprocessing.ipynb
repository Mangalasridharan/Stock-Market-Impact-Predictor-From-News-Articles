# %%
import pandas as pd

# %%
df_main = pd.read_parquet(r'F:\College\SEM 7\19CSE453-Natural Language Processing\Case Study\Dataset\train-00000-of-00048.parquet')
df_main
# Out:
#        Unnamed: 0                     Date  \
# 0             0.0  2023-12-16 23:00:00 UTC
# 1             1.0  2023-12-12 00:00:00 UTC
# 2             2.0  2023-12-12 00:00:00 UTC
# 3             3.0  2023-12-07 00:00:00 UTC
# 4             4.0  2023-12-07 00:00:00 UTC
# ...           ...                      ...
# 323939   323939.0  2015-05-26 00:00:00 UTC
# 323940   323940.0  2015-05-26 00:00:00 UTC
# 323941   323941.0  2015-05-25 00:00:00 UTC
# 323942   323942.0  2015-05-22 00:00:00 UTC
# 323943   323943.0  2015-05-21 00:00:00 UTC
#
#                                             Article_title Stock_symbol  \
# 0       Interesting A Put And Call Options For August ...            A
# 1       Wolfe Research Initiates Coverage of Agilent T...            A
# 2       Agilent Technologies Reaches Analyst Target Price            A
# 3       Agilent (A) Enhances BioTek Cytation C10 With ...            A
# 4       Pre-Market Most Active for Dec 7, 2023 : SQQQ,...            A
# ...

# %%
df_dropped=df_main.drop(columns=['Url','Publisher','Author','Lsa_summary','Luhn_summary','Textrank_summary','Lexrank_summary'],axis=1)

# %%
df_dropped['Date']=pd.to_datetime(df_dropped['Date'])

# %%
start_time="2018-01-01"
end_time="2023-12-31"

df_filtered=df_dropped[(df_dropped['Date']>=start_time) & (df_dropped['Date']<=end_time)]

# %%
df_filtered
# Out:
#        Unnamed: 0                      Date  \
# 0             0.0 2023-12-16 23:00:00+00:00
# 1             1.0 2023-12-12 00:00:00+00:00
# 2             2.0 2023-12-12 00:00:00+00:00
# 3             3.0 2023-12-07 00:00:00+00:00
# 4             4.0 2023-12-07 00:00:00+00:00
# ...           ...                       ...
# 323558   323558.0 2018-01-09 00:00:00+00:00
# 323559   323559.0 2018-01-09 00:00:00+00:00
# 323560   323560.0 2018-01-09 00:00:00+00:00
# 323561   323561.0 2018-01-05 00:00:00+00:00
# 323562   323562.0 2018-01-05 00:00:00+00:00
#
#                                             Article_title Stock_symbol  \
# 0       Interesting A Put And Call Options For August ...            A
# 1       Wolfe Research Initiates Coverage of Agilent T...            A
# 2       Agilent Technologies Reaches Analyst Target Price            A
# 3       Agilent (A) Enhances BioTek Cytation C10 With ...            A
# 4       Pre-Market Most Active for Dec 7, 2023 : SQQQ,...            A
# ...

# %%
df_filtered.to_csv(r'F:\College\SEM 7\19CSE453-Natural Language Processing\Case Study\Dataset\filtered_data.csv')
